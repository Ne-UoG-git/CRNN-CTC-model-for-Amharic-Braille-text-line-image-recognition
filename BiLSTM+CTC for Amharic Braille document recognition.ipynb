# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import fnmatch
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Reshape, Bidirectional, LSTM, Dense, Lambda, Activation, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences
from google.colab import drive
drive.mount('/content/drive')
from os import listdir
from os.path import isfile, join
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import backend as tf_keras_backend 

tf_keras_backend.set_image_data_format('channels_last')
tf_keras_backend.image_data_format()
import glob
# Out:
# Mounted at /content/drive

# %%
from skimage.filters import sobel
from skimage.util import invert
from skimage.color import rgb2gray
imgs=[]
ims=[]
img_list = sorted(glob.glob('/content/drive/MyDrive/Colab_Notebooks/Nega/line-images/*.PNG'))
for i, img_path in enumerate(img_list):
  ims = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
  th2 = cv2.adaptiveThreshold(ims,170,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,35,25)
  imgs.append(th2)

# %%
dim=(256, 48)
def im_resize(input_image):
    #f=cv2.transpose(input_image)
    im_resize=cv2.resize(input_image, dim)
    return im_resize

# %%
train = []
valid = []

for i in range(len(imgs)):
    image = im_resize(imgs[i])
    image = image/255.
    if i%10 == 0:     
        valid.append(image)
    else:
      train.append(image)

# %%
alphabets = ' ሀሁሂሃሄህሆለሉሊላሌልሎሐሑሒሓሔሕሖመሙሚማሜምሞሰሱሲሳስሶረሩሪራሬርሮሠሡሢሣሤሥሦሸሹሺሻሼሽሾቀቁቂቃቄቅቆበቡቢባቤብቦተቱቲታቴትቶቸቹቺቻቼችቾኀኃነኑኒናኔንኖኘኙኚኛኜኝኞአኡኢኣኤእኦከኩኪካኬክኮኸኹኺኻኼኽኾወዉዊዋዌውዎዐዑዒዓዔዕዖዘዙዚዛዜዝዞዠዡዢዣዤዥዦየዩዪያዬይዮደዱዲዳዴድዶጀጁጂጃጄጅጆገጉጊጋጌግጎጠጡጢጣጤጥጦጨጩጪጫጬጭጮጰጱጲጳጴጵጶጸጹጺጻጼጽጾፀፁፂፃፄፅፆፈፉፊፋፌፍፎፐፑፒፓፔፕፖቨቩቪቫቬቭቮ0123456789፥፣()-ሏሟሷሯሿቧቆቈቋቷቿኗኟዟዧዷጇጧጯጿፏኳኋኧቯጐጕጓ።' 
chars = ' ጊዙሥኣዩጎ8ጸጓድፌጢ3ኡዋቡቺቅኝልእዟኛጤጣቫቦታዚሽሜኒዊሢ2ጥሕሱዴሡምኜኞውቆዜሃቬጫሬከይቭጨሰሌክቂቹጲፈ9ህቀርዳቁቢሂሉዶዓጵዥፀጾሎኑ4ሯቃሠ፣ዪሳኤኗ5ዖቾኧፕዔበኬያዲኢቷጪፒዌሤዕቪኖጠባኦናዮሷፉፔቼሞፓደዷሀጉፖሁሒ0ዱዝዐቲቻዘግ7ዢሓጄ፥ኪ-ሟማሼሹጦፎሮጭፋየብሩቤሄዠዞዎሙንለኽቮሊቸሔፆኘዛኺሦስፊሐ1ኮቿመ።ሸሚጮካትፄረኋሶችኼላአተሪሆ6ሺጂገቴሑሖቨቱዣሻኩጁሲፃ)ጧጡጃጋጅዒሏኸዉፍኙሣ(ጀቶጽዬኳጆቄኔፏራወነፅጻቋ'
chr =' ኦሪዌጭጂቪዣያቆቻጤፎቹራ0ሠጣኑፏሃኳ7ሩዚጫጶአሽጢሲጧንጮሤቴጰ.ግፊጲሺቁኖፒዤቄጵቷሯኛዎፁሸሉጺጯኡቫሙዛቦዋ5ሦፆዐካዳኒጆወጋሿሂ3ጡህዩሚሣቲቿኙዊርሄቬመቨሜኸጨሬይሻሹፓጅዬጬጹጃባጀትዞዱደኘዶፅገቩሳ1ፋቤዥቶዟዝ8ጻኩፀቡኤነክፖለ4ኅጪጠበቢሕጩሏቀዘቅከኝጎ።ኪችፍፔ9ሓፃሖቋሐውስቮጌኣሞ2ሮምሡላዜዙዕፌቸጸጦዮረጁሊናኞተዲሾሷሥጽታዉሔሟሁጉሎ?ኗኔየሌጊልኮኋጥማሆእ6ፕብኼሀቭኬጼዷድዴኽፈቂሢኢጓፉቱቃ'
num_of_characters = len(chr) + 1 # +1 for ctc pseudo blank(epsilon)

num_of_timestamps = 24 # max length of predicted labels


def label_to_num(label):
    label_num = []
    for ch in label:
        label_num.append(chars.find(ch)) 
        #find() method returns the lowest index of the substring if it is found in given string otherwise -1
        
    return np.array(label_num)

def num_to_label(num):
    ret = ""
    for ch in num:
        if ch == -1:  # CTC Blank
            break
        else:
            ret+=chars[ch]
    return ret

# %%
max_label_len=0

train_y = []
train_input_len = []
train_label_len = []
train_original_text = []

valid_y = []
valid_input_len = []
valid_label_len = []
valid_original_text = []
with open('/content/drive/MyDrive/Colab_Notebooks/Nega/label.txt', encoding="utf-8") as f:
    contents = f.readlines()[0:]

lines = [line.strip() for line in contents]
for i in range(len(lines)):
    try:
      if len(lines[i]) > max_label_len:
          max_label_len = len(lines[i])
      if i%10 == 0:     
          valid_original_text.append(lines[i])   
          valid_label_len.append(len(lines[i]))
          valid_input_len.append(32) #what is 61 here?
          valid_y.append(label_to_num(lines[i]))
      else:
        train_original_text.append(lines[i])   
        train_label_len.append(len(lines[i]))
        train_input_len.append(32) #can i make it 32?
        train_y.append(label_to_num(lines[i]))
    except Exception as e:
        print("Label Encoding Error Occurred", e)

# %%
train_x = np.asarray(train).reshape(-1, 48, 256, 1)#array will get reshaped in such a way that the resulting array has only 1 column
valid_x = np.asarray(valid).reshape(-1, 48, 256, 1) #(16384,1)

train_pad_txt = pad_sequences(train_y, maxlen=max_label_len, padding='post', value = 0)
valid_pad_txt = pad_sequences(valid_y, maxlen=max_label_len, padding='post', value = 0)

train_input_length=np.asarray([train_input_len[i] +30 for i in range (len(train_y))]) # +15 is her to have equivalant length ( 2*24-2= 47 then 32 is the input lenght of each image then 32+15 going to be 47)
valid_input_length=np.asarray([valid_input_len[i] +30 for i in range (len(valid_y))])

train_label_length=np.asarray([train_label_len[i] for i in range (len(train_y))])
valid_label_length=np.asarray([valid_label_len[i] for i in range (len(valid_y))])

# %%
valid_pad_txt[3]
# Out:
# array([ 91,  44, 177,   0, 149, 179, 176, 184, 191,  44,   0, 190, 221,
#          0, 159,  41, 132, 150, 234,   0,   0,   0,   0,   0], dtype=int32)

# %% [markdown]
# ## Building our model

# %%
input_data = Input(shape=(48, 256, 1), name='input')

con1 = Conv2D(64, (3, 3), activation = 'relu', padding='same', name='conv1', kernel_initializer='he_normal')(input_data)  
pool1 = MaxPooling2D(pool_size=(2, 2), name='max1')(con1)

con2 = Conv2D(128, (3, 3), activation = 'relu', padding='same', name='conv2', kernel_initializer='he_normal')(pool1)
pool2 = MaxPooling2D(pool_size=(2, 2), name='max2')(con2)

con3 = Conv2D(256, (3, 3), activation = 'relu', padding='same', name='conv3', kernel_initializer='he_normal')(pool2)

con4 = Conv2D(256, (3, 3), activation = 'relu', padding='same', name='conv4', kernel_initializer='he_normal')(con3)
pool3 = MaxPooling2D(pool_size=(2, 1), name='max3')(con4)

con5 = Conv2D(512, (3, 3), activation = 'relu', padding='same', name='conv5', kernel_initializer='he_normal')(pool3)
norm1 = BatchNormalization()(con5)

con6 = Conv2D(512, (3, 3), activation = 'relu',  padding='same', name='conv6', kernel_initializer='he_normal')(norm1)
norm2 = BatchNormalization()(con6)
pool4 = MaxPooling2D(pool_size=(3, 1), name='max5')(norm2)

con7 = conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool4)


# CNN to RNN
squeezed = Lambda(lambda x: K.squeeze(x, 1))(con7)

## RNN
inner1 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.2), name = 'lstm1')(squeezed)
inner2 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.2), name = 'lstm2')(inner1)

## OUTPUT
dense = Dense(len(chars)+1, kernel_initializer='he_normal',name='dense2')(inner2)
outputs = Activation('softmax', name='softmax')(dense)

pred_model = Model(inputs=input_data, outputs=outputs)
pred_model.summary()
# Out:
# Model: "model_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 256, 1)]      0
#
#  conv1 (Conv2D)              (None, 48, 256, 64)       640
#
#  max1 (MaxPooling2D)         (None, 24, 128, 64)       0
#
#  conv2 (Conv2D)              (None, 24, 128, 128)      73856
#
#  max2 (MaxPooling2D)         (None, 12, 64, 128)       0
#
#  conv3 (Conv2D)              (None, 12, 64, 256)       295168
#
#  conv4 (Conv2D)              (None, 12, 64, 256)       590080
#
#  max3 (MaxPooling2D)         (None, 6, 64, 256)        0
#
#  conv5 (Conv2D)              (None, 6, 64, 512)        1180160
#
#  batch_normalization_78 (Bat  (None, 6, 64, 512)       2048
#  chNormalization)
#
#  conv6 (Conv2D)              (None, 6, 64, 512)        2359808
#
#  batch_normalization_79 (Bat  (None, 6, 64, 512)       2048
#  chNormalization)
#
#  max5 (MaxPooling2D)         (None, 2, 64, 512)        0
#
#  conv2d_39 (Conv2D)          (None, 1, 63, 512)        1049088
#
#  lambda_33 (Lambda)          (None, 63, 512)           0
#
#  lstm1 (Bidirectional)       (None, 63, 256)           656384
#
#  lstm2 (Bidirectional)       (None, 63, 256)           394240
#
#  dense2 (Dense)              (None, 63, 239)           61423
#
#  softmax (Activation)        (None, 63, 239)           0
#
# =================================================================
# Total params: 6,664,943
# Trainable params: 6,662,895
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
the_labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, the_labels, input_length, label_length])

#model to be used at training time
model = Model(inputs=[input_data, the_labels, input_length, label_length], outputs=loss_out)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=Adam(learning_rate=0.0001))
# the loss calculation occurs elsewhere, so we use a dummy lambda function for the loss

file_path_best = "/content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5"
checkpoint = ModelCheckpoint(filepath=file_path_best, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint]

# %%
history = model.fit(x=[train_x, train_pad_txt, train_input_length, train_label_length], y=np.zeros(len(train_x)), batch_size=32, epochs=30,
                          validation_data=([valid_x, valid_pad_txt, valid_input_length, valid_label_length], [np.zeros(len(valid_x))]),
                          callbacks = callbacks_list, verbose=1)
# Out:
# Epoch 1/30
# 56/57 [============================>.] - ETA: 0s - loss: 3.5783
# Epoch 1: val_loss did not improve from 4.12673
# 57/57 [==============================] - 6s 108ms/step - loss: 3.5763 - val_loss: 4.4190
# Epoch 2/30
# 57/57 [==============================] - ETA: 0s - loss: 3.2638
# Epoch 2: val_loss improved from 4.12673 to 3.53400, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 7s 129ms/step - loss: 3.2638 - val_loss: 3.5340
# Epoch 3/30
# 56/57 [============================>.] - ETA: 0s - loss: 2.9535
# Epoch 3: val_loss improved from 3.53400 to 3.48098, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 114ms/step - loss: 2.9545 - val_loss: 3.4810
# Epoch 4/30
# 56/57 [============================>.] - ETA: 0s - loss: 2.7349
# Epoch 4: val_loss improved from 3.48098 to 3.34723, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 114ms/step - loss: 2.7357 - val_loss: 3.3472
# Epoch 5/30
# 56/57 [============================>.] - ETA: 0s - loss: 2.4917
# Epoch 5: val_loss improved from 3.34723 to 3.11697, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 114ms/step - loss: 2.4905 - val_loss: 3.1170
# Epoch 6/30
# 56/57 [============================>.] - ETA: 0s - loss: 2.2713
# Epoch 6: val_loss improved from 3.11697 to 3.04017, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 114ms/step - loss: 2.2711 - val_loss: 3.0402
# Epoch 7/30
# 56/57 [============================>.] - ETA: 0s - loss: 2.0817
# Epoch 7: val_loss improved from 3.04017 to 2.88253, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 113ms/step - loss: 2.0812 - val_loss: 2.8825
# Epoch 8/30
# 57/57 [==============================] - ETA: 0s - loss: 1.9132
# Epoch 8: val_loss improved from 2.88253 to 2.77704, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 113ms/step - loss: 1.9132 - val_loss: 2.7770
# Epoch 9/30
# 56/57 [============================>.] - ETA: 0s - loss: 1.7753
# Epoch 9: val_loss improved from 2.77704 to 2.68761, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 112ms/step - loss: 1.7744 - val_loss: 2.6876
# Epoch 10/30
# 56/57 [============================>.] - ETA: 0s - loss: 1.6239
# Epoch 10: val_loss did not improve from 2.68761
# 57/57 [==============================] - 6s 107ms/step - loss: 1.6243 - val_loss: 2.7070
# Epoch 11/30
# 56/57 [============================>.] - ETA: 0s - loss: 1.5257
# Epoch 11: val_loss improved from 2.68761 to 2.45749, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 8s 136ms/step - loss: 1.5266 - val_loss: 2.4575
# Epoch 12/30
# 56/57 [============================>.] - ETA: 0s - loss: 1.3937
# Epoch 12: val_loss did not improve from 2.45749
# 57/57 [==============================] - 6s 106ms/step - loss: 1.3905 - val_loss: 2.5094
# Epoch 13/30
# 56/57 [============================>.] - ETA: 0s - loss: 1.2658
# Epoch 13: val_loss improved from 2.45749 to 2.42783, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 7s 115ms/step - loss: 1.2677 - val_loss: 2.4278
# Epoch 14/30
# 57/57 [==============================] - ETA: 0s - loss: 1.1911
# Epoch 14: val_loss improved from 2.42783 to 2.36972, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 7s 124ms/step - loss: 1.1911 - val_loss: 2.3697
# Epoch 15/30
# 56/57 [============================>.] - ETA: 0s - loss: 1.0995
# Epoch 15: val_loss improved from 2.36972 to 2.34572, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 112ms/step - loss: 1.0990 - val_loss: 2.3457
# Epoch 16/30
# 57/57 [==============================] - ETA: 0s - loss: 1.0303
# Epoch 16: val_loss improved from 2.34572 to 2.28641, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 114ms/step - loss: 1.0303 - val_loss: 2.2864
# Epoch 17/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.9507
# Epoch 17: val_loss improved from 2.28641 to 2.16214, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 113ms/step - loss: 0.9487 - val_loss: 2.1621
# Epoch 18/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.8965
# Epoch 18: val_loss did not improve from 2.16214
# 57/57 [==============================] - 6s 108ms/step - loss: 0.8952 - val_loss: 2.1813
# Epoch 19/30
# 57/57 [==============================] - ETA: 0s - loss: 0.8044
# Epoch 19: val_loss did not improve from 2.16214
# 57/57 [==============================] - 6s 110ms/step - loss: 0.8044 - val_loss: 2.1794
# Epoch 20/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.7367
# Epoch 20: val_loss improved from 2.16214 to 2.08365, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 8s 133ms/step - loss: 0.7391 - val_loss: 2.0837
# Epoch 21/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.6948
# Epoch 21: val_loss improved from 2.08365 to 2.05256, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 113ms/step - loss: 0.6956 - val_loss: 2.0526
# Epoch 22/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.6543
# Epoch 22: val_loss did not improve from 2.05256
# 57/57 [==============================] - 6s 106ms/step - loss: 0.6540 - val_loss: 2.0566
# Epoch 23/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.6064
# Epoch 23: val_loss improved from 2.05256 to 2.03021, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 8s 132ms/step - loss: 0.6059 - val_loss: 2.0302
# Epoch 24/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.5661
# Epoch 24: val_loss improved from 2.03021 to 1.98004, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 112ms/step - loss: 0.5677 - val_loss: 1.9800
# Epoch 25/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.5426
# Epoch 25: val_loss improved from 1.98004 to 1.95098, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 112ms/step - loss: 0.5417 - val_loss: 1.9510
# Epoch 26/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.4908
# Epoch 26: val_loss improved from 1.95098 to 1.93888, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 112ms/step - loss: 0.4932 - val_loss: 1.9389
# Epoch 27/30
# 57/57 [==============================] - ETA: 0s - loss: 0.4569
# Epoch 27: val_loss improved from 1.93888 to 1.91060, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 113ms/step - loss: 0.4569 - val_loss: 1.9106
# Epoch 28/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.4304
# Epoch 28: val_loss improved from 1.91060 to 1.84197, saving model to /content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4803.hdf5
# 57/57 [==============================] - 6s 114ms/step - loss: 0.4299 - val_loss: 1.8420
# Epoch 29/30
# 57/57 [==============================] - ETA: 0s - loss: 0.3983
# Epoch 29: val_loss did not improve from 1.84197
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3983 - val_loss: 1.8842
# Epoch 30/30
# 56/57 [============================>.] - ETA: 0s - loss: 0.3796
# Epoch 30: val_loss did not improve from 1.84197
# 57/57 [==============================] - 6s 110ms/step - loss: 0.3793 - val_loss: 1.8804

# %%
#plot accuracy and loss
def plotgraph(epochs, acc, val_acc):
    # Plot training & validation accuracy values
    plt.plot(epochs, acc, 'b')
    plt.plot(epochs, val_acc, 'r')
    plt.title('Training Vs Validation loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Val'], loc='upper right')
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(loss)+1)
#loss = range(1,len(loss)+1)

plotgraph(epochs, loss, val_loss)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-3d1a35243f05> in <module>
#       9     plt.legend(['Train', 'Val'], loc='upper right')
#      10 plt.show()
# ---> 11 acc = history.history['accuracy']
#      12 val_acc = history.history['val_accuracy']
#      13 loss = history.history['loss']
#
# KeyError: 'accuracy'

# %%
model.save_weights('/content/drive/MyDrive/Colab_Notebooks/Nega/history4201.hdf5')

# %%
model=model.load_weights('/content/drive/MyDrive/Colab_Notebooks/Nega/C_LSTM_best4802.hdf5')

# %% [markdown]
# ## Check model performance on validation set

# %%
# please use this one for prediction
y_pred=pred_model.predict(train_x)

out = K.get_value(K.ctc_decode(y_pred[:, :, :], input_length=np.ones(y_pred.shape[0]) * y_pred.shape[1])[0][0])
prd_train = []
for i in range(1800):
    prd_train.append(num_to_label(out[i]))
# Out:
# 57/57 [==============================] - 3s 29ms/step

# %%
#please don't use model during testing pred_model is the one
preds = pred_model.predict(valid_x)
decoded = K.get_value(K.ctc_decode(preds, input_length=np.ones(preds.shape[0])*preds.shape[1], 
                                    greedy=True)[0][0])
prd_valid = []
for i in range(200):
    prd_valid.append(num_to_label(decoded[i]))
# Out:
# 7/7 [==============================] - 0s 26ms/step

# %%
print(prd_valid)
# Out:
# ['ክች ይገኛሉ። የሥጋ ከብት እርሻ-', 'ሠጡ የሚችሉ የከብት ዝርያዎች', 'ዙ ቁ ያለው የከብት አላት። ነ', 'ኧው። የሚመረተው አሣ ለምግብነ', 'ያን ይሁን እንጂ በአሣ ማምረት', 'ኧማሩትም ጥቂት ሠዎች ናቸው። አ', 'ብለመደረጉ የአሣዎችን እልቂት', 'ጠንካራ ፍለጋ ይጠይቃል። ማእድን', '2 ጥልቀት 3 ጥቃት 4 እውቀት 5', 'ቅድሚያ እነዚህ ነገሮች መጠና', 'ኧጥሮ ነዳጅ የተፈጥሮ ጋዝ ጥጥር', 'ክንያ ወዘተ። 2 በብረት ዩ ሥ', 'ብብሪካ ወደ ምርትነት ይለወጣል።', 'ጭማ የሥር የቄት የሣሙናን', 'የሥራ እድል ይከፍታሉ። የው ምንዝ', 'ኧቱ በርካታ አለም አቀፍ የኢ', 'ና እሥፓን ነበሩ ከድርጅቱ ዋና', 'ፍ ማህበረሠብ በመባል ይጠራ ይ', 'ኧተባበሩት መንግሥታት ድርጅት ከም', 'ች ሢሆን በአሁኑ ወቅት የአብ', 'ዋሥትና ሥለሚሠጥ ኢንቨሥትመንትን', 'ዲሥፋፋ መርዳት የውጪ ምንዛሪ', 'ጋሉ። ምዕራፍ 2 የሠው ሀይል አ', 'ለበት እንደአፍሪካ ድሃ አህጉር', 'ኧው። በመሆኑም የአፍሪካ ሀገ', 'ጠያይቅም ሀላፊነት የሚሠማው', 'ዋና ዋናዎቹ የሚከተሉት ና', 'ች አኗኗር አለ ሀብታም ደሃ ይ', 'ህዝቦች መሠረታዊ የሆነ ፍላግ', 'ኧበቀና ተገቢነት ያለው 19።', 'ብቻ እንደሆነ ካደገና በማደ', 'ረት በመሥጠት 1994 አ።ም ጀምር', 'ላይ ይገኛል። አዲሡ የትምህርት ብ', 'ለው በአንጻሩ ደግሞ በህብረተ', 'ቀም ላይ ከፍተኛ የሆነ አሉት', 'ልሥከተል ለተጨማሪ በጊዜው ክ', 'ሙ ቀርተዋል። ምዕራፍ 3 የኤድሥ', 'ዝኔታን የሚፈጥር ቫይረሥ ነው።', 'ምፃረቃል የተወሠደው አሟየር', 'የተለያዩ የበሽታ አይነቶች', 'በቫይረሡ ከተጠቁ እና ቶች የ', 'ው የሚደርሡበት ችግሮች በግለሠ', 'ፍረሥ ወዘተ  በግለሠቡ ኢኮን', 'ኧሆነና በፍቃደኝነት ላይ የተ', 'ንዲቀበሉና ተጽዕኖዎችን እንዲቅ', 'ኧቅም የሚፈታተን ጫና ይፈጥራል', 'ግብ ምርቶች ማምረት ሥለሚገፋፉ', 'ድሥ ማንኛውም ቫይረሡ የተላለፍ', 'ድዊ ግዴታ ነው። ምዕራፍ 4 ዋና', 'ም መሣሪያ ሢፈጥሩ -ነባሩን', 'ፕን ሊያሥገኝ ችሏል። ማርኮኒ ባ', 'ውያዎችና በብዙ ሺህ ኪሜ ርቀ', 'ዳጅ ጀምሥ ዋት የሚባል አውሮፓ', 'ኧሥራን ክንውንን ከወትሮ ማፋጠን', 'ብደቶችን በውፋጮ በባቡርና በ', 'ከተሉት ወሣኝ ግኝቶች 1 ነበ', 'ነልካም ሥነ-ምግባር ራሥን የመሩ', 'ጊዜ ፋብሪካዎች ካለ ኮረንቲ', 'ሠልጣኔውም ሀይል የሆነውን ኮረ', 'ስም ትውልድ ለማቆየት በዋሻዎች', 'ኧው ይባዙ ነበረ። መፀሀፍትን ብ', 'ዘመን ተማሪዎች እንዳሁኖቹ ይ', 'ሀገር ባደረገው ሙከራ ለመጅ', 'ኧሠራጨት ተችሏል። ይህ ግኝት ትምህር', 'ኧመብረር ምኞት ከተጠናወታቸው', 'ህድቸውም ከነሡ በፊት የተደር', 'በማሥወገድ አሥፈላጊውን ጥረት', 'በመቋቋም ሙከራቸውን ቀጥሎ ብ', 'በህዳር ወር 1903 አ።ም ነበር', 'ክና የፈጠራ ሥራ ምጥቀት ተቋም', 'ሙከራ የተጀመረ በራሪ እድግ', 'ክች ዊልቨር ራይት በ191 እሊዝ', 'ኧጥረው በማለፋቸው በሁሉም የ', 'ምሮ ሢያደርግ የነበረው ጥረት', 'ከተል እናቀርባለን። ሂፖ ክራት', 'ና በአምልክዊ ተግባራት የ፥', 'የሚገባውን ሥነ-ምግባር በግልጽ ይ', 'ስሞችን ክብርና ተግባር እንዲጠብቁ', 'ር፥ በ18 አ።ም የተወለደ46።', 'ኧሚፈፀም ለመጀመሪያ ጊዜ ይ', 'ውሻ በሽታ በመከላከልና ፈውሥ', 'ሞተር ሀይል ይንቀሣቀሣሉ የሠ', 'እንፋሎት ሀይል የሚንቀሣቀሥ አ', 'ን የሚሠራ እንጅን በመፈልሠፍ ል', 'ትሪክ የሚሠሩ ተሽከርክ ሪዎችክ', ' አ።አ ድረሥ የባቡር ሃዲድ ል', 'ኋላም ብዙ ሣይሠራ ፈነዳ። የ', 'የአመቱ በርካታ መኪናዎች ም', 'ነቶች በሀገሮች መሀከል ተካ', 'ሽት ሢሆን ዋና ዋናዎቹ የሚክ', 'ቦች ነፃ የመውጣትና የራሥን ን', 'ግዛት እሽቅድምድም፥ ይህ ወቅት የአውር', 'ረት መፈጠር ከላይ የተጠቀሡ', 'ሉ የአለም ሃያላን ሀገሮች ብ', 'እርነት ለመጫር ሠበብ ሢፈልጉ', 'እልም መገደል ላንደኛው አለም', 'ል መንግሥት እንዲፈቅድ የሚጠይቅ ን', 'ይማኖት  የሆርቶዶክሥ እምነት ተ', 'ኧይነት የወቅቱ ሃያላን ሀገሮ', 'ጦርነቱን ተያያዙት። ጦርነት ብ', 'ሌድልው ጦርነት የተፈለገውን ድል', 'የጫኑ መርከቦችን ባህር ውሥጥ በ', 'ኧ2 አቅጣጫ በ1 ጊዜ ጦርነት', 'የበላይነት ነበራቸው። ለ191', 'በመጨረሻም እ።አ።አ በ1918', 'ልድኞች ወዘተ። ጦርነቱ ከ337', 'ት ሆናለች ይጎዝላቪያም 1 ነፅ', 'መንግሥታት ማህበር አመሠራረት፥', 'ሥጥ ነው። በጉባኤው የተወሠኑ', 'እድል በውሣኔ ዝብ እንዲወሥን የር', 'ውሣኔ ውጤቶች በቀጣይ ለተከል', 'ኧመሥረትና አላማዎች ምሥረታ።', 'ርጅት ለማቋቋም ተሥማሙ። በሥምም', 'ስም ሀገሮች መካከል የሚፈጠር', 'ም መንግሥታት ማህበር አባል መሆ', 'ትዮጲያ እንዲዳከም አሥተዋዕፅ', 'ኧረባሪያ ንግድ አዋጅ በ1924', 'ኢትዮጲያ እንዲገባ በር ከፍቷ', 'እንደ ኢጣሊያን አልነበረም። ም', 'ድ አ።ም ኢጣሊያ ኢትዮጲያን ው', 'ኧር ሣይችል ቀርቷል። ከነዚህም ምክ', 'ሀይል የሌለው መሆን ሥለዚህም ው', 'ደቀው በቨርሣይዕሉ ያ1ኛው የ', 'ኧአባል ሀገሮች ተገቢውን ድጋፍ', 'ኧተጠቀሡት የማህበሩ ድክመቶች', 'እየተባለ ይጠራል። መንሤኤዎች', 'ር ኦሥታሊያና ቺኮላቪኪያ ሥ', 'የኢኮኖሚ ቀውሥ ውሥጥ ነበሩ።', 'ይዶልፍ ሂትለር እየተመራ መሥከ', 'ጦርነቱም የተባበሩት የጋላክ', 'መን በኛ የአለም ጦርነት', 'ቪያን ሊቱኒያን ከ1939-194', 'ን ያዘ በፈረንሣይም በፓርሻል', 'ቻለ የሠሜን አፍሪካ ጦርነትን', 'ንግሊዝ ጦር የኢጣሊያን ጦር ድል', 'ኧ።ም ተሸነፈ። ሠሜን አፍሪካም', 'ይ የከፈተው ጥቃት የባርባሮሥ', 'ጎናፀፈ። የሦቪት በጀርመን ጥ', 'ፍዳ የጃፓን ጦር በፓሥፊክ የህ', 'ን መጠናቀቅ ፥ በ1944 በጄኔ', 'ረንሣይ ጦር ጀርመንን ማጥቃት ጀ', 'ተብሎ መታሠብ ጀመረ። በ194', 'ኧጦር አውሮፕላኖች 2 የጃፓን', 'ች፥ ጦርነቱ ያሥከተላቸው የኢ', 'ቢሊዮን የሚቆጠር ገንዘብ ፈሥ', 'ሥሦሻሊሥት ምእራብ ጀርመን እካፒት', 'ፅ ያከናወናቸው ሥራዎች፥ የምሥ', 'ግተን 26 ሀገሮች የአትላንቲክ', 'ኧ10 አመታት ያህል በ2 ሀገር', '2ንም አገሮች ለማሥማማት ጥረት', 'በአገሪቱ ላይ የኢኮኖሚ ማ', 'ች መንግሥታት ሆነው እንዲመሠርቱ', 'ከላኩ የተባበሩት መንግሥታት', 'ቀባል አገሮች ውሥጥ ኢትዮጲያ', 'ኧወቅቱ ሀያላን መንግሥታትም በእ', 'ዊ ጉባኤ በሣንፍራንሢ ሥኮ አ', 'አመት ያገለግላሉ። ይህ ምክር65', 'ት ተሸናፊ የሆኑት ጀርመን ኢ', 'አካል ሢሆን ህግ ነክ ጉዳዮችን', 'ህደ እንደመሆኑ መጠን ተሸናፍ', 'ዳክሞ ሥለነበር ቀኝ ግዛቶቻቸ', 'ማት ወድመዋል። ሥለሆነም አብዛ', 'ኮሙኒሥት አሥተዳደር የነበረ', 'ትግል ጀመሩ። የድርጅቱ ወታደራ', 'የትንሃሞች ተዋሃዱ ፀረ-ቀኝ', 'ራ መሠዋእትነት የተከፈለበት', 'ቀሠው ጦርነት ከ1954 እሥከ 1', 'ኧቷን ያገኘች ብቸኛዋ አፍሪካ', 'ማህበር ተቋቁሞ በመጀመሪያ', 'ጅት ነበር። ይህ ሚሥኢራዊ ድርጅት', 'ደደደች። ዚምባብውና ዛምብቢያ፥', 'በኋላ በ194 አፓርታይድ ተግ', 'ሚጀምረው ከዛሬ 2000 አመት', 'አካል በማድረግ ይዘውት ነበር።', 'ቄ አንሥተው መታገል ጀመሩ። እ', 'በች። ድርጅቱም በአካባቢው 2 ይ', 'ፅ  ...

# %%
y_true = valid_original_text   #Character Error Rate
correct_char = 0
total_char = 0
correct_seq = 0
corect_char=0
error_chr=0
error_seq=0
pp=[]
pt=[]
gt=[]
rt=[]
err=0
for i in range(200):
    pr = prd_valid[i]
    tr = valid_original_text[i]
    total_char += len(tr)
    #err += Levenshtein.distance(pr, tr)
    if pr == tr :
      correct_seq += 1
    else:
      gt.append(pr)
      rt.append(tr)
      error_seq+=1 
    for j in range(min(len(tr), len(pr))):
        if tr[j] == pr[j]:
            correct_char+= 1
        else:
          pp.append(pr[j])
          pt.append(tr[j])
    for j in range(min(len(pr), len(tr))):
        if pr[j] == tr[j]:
          corect_char+= 1
        else:
          error_chr+=1        
    
print(gt)
print(rt)
print('Correct characters Rate : %.2f%%' %(corect_char*100/total_char))   
print('Charcter Error Rate : %.2f%%' %(error_chr*100/total_char))
print('Correct Sequence Rate : %.2f%%' %(correct_seq*100/200))
print('Seqence Error Rate : %.2f%%' %(error_seq*100/200))
# Out:
# ['ክንያ ወዘተ። 2 በብረት ዩ ሥ', 'ጭማ የሥር የቄት የሣሙናን', 'የሥራ እድል ይከፍታሉ። የው ምንዝ', 'ና እሥፓን ነበሩ ከድርጅቱ ዋና', 'ች ሢሆን በአሁኑ ወቅት የአብ', 'ላይ ይገኛል። አዲሡ የትምህርት ብ', 'ልሥከተል ለተጨማሪ በጊዜው ክ', 'በቫይረሡ ከተጠቁ እና ቶች የ', 'ፍረሥ ወዘተ  በግለሠቡ ኢኮን', 'ድሥ ማንኛውም ቫይረሡ የተላለፍ', 'ም መሣሪያ ሢፈጥሩ -ነባሩን', 'ውያዎችና በብዙ ሺህ ኪሜ ርቀ', 'ብደቶችን በውፋጮ በባቡርና በ', 'ከተሉት ወሣኝ ግኝቶች 1 ነበ', 'ነልካም ሥነ-ምግባር ራሥን የመሩ', 'ስም ትውልድ ለማቆየት በዋሻዎች', 'ሀገር ባደረገው ሙከራ ለመጅ', 'ህድቸውም ከነሡ በፊት የተደር', 'ክች ዊልቨር ራይት በ191 እሊዝ', 'ና በአምልክዊ ተግባራት የ፥', 'ር፥ በ18 አ።ም የተወለደ46።', 'ሞተር ሀይል ይንቀሣቀሣሉ የሠ', 'እንፋሎት ሀይል የሚንቀሣቀሥ አ', 'ትሪክ የሚሠሩ ተሽከርክ ሪዎችክ', ' አ።አ ድረሥ የባቡር ሃዲድ ል', 'እልም መገደል ላንደኛው አለም', 'ል መንግሥት እንዲፈቅድ የሚጠይቅ ን', 'ይማኖት  የሆርቶዶክሥ እምነት ተ', 'ሌድልው ጦርነት የተፈለገውን ድል', 'ሥጥ ነው። በጉባኤው የተወሠኑ', 'እድል በውሣኔ ዝብ እንዲወሥን የር', 'ውሣኔ ውጤቶች በቀጣይ ለተከል', 'ም መንግሥታት ማህበር አባል መሆ', 'ኧረባሪያ ንግድ አዋጅ በ1924', 'ር ኦሥታሊያና ቺኮላቪኪያ ሥ', 'መን በኛ የአለም ጦርነት', 'ሥሦሻሊሥት ምእራብ ጀርመን እካፒት', 'ቀባል አገሮች ውሥጥ ኢትዮጲያ', 'ጅት ነበር። ይህ ሚሥኢራዊ ድርጅት', 'ደደደች። ዚምባብውና ዛምብቢያ፥', 'በኋላ በ194 አፓርታይድ ተግ', 'ሜ ሙሥጠፋ ወዘተ ናቸው። -', 'አሉት። ቀጥለው የቀረቡት ዋና', 'ለእርሻና ለዘሩ አይነት የሚል', 'ብረት የሚመራ የሥሻሊሥት (', 'ነጻነታቸውን ተጎናሥፈዋል።']
# ['ክንዥያ ወዘተ። 2 በብረት ዩ ሥ', 'ጭማ የሥኳር የዱቄት የሣሙናን', 'የሥራ እድል ይከፍታሉ። የውጭ ምንዝ', 'ና እሥፔን ነበሩ ከድርጂቱ ዋና', 'ርች ሢሆን በአሁኑ ወቅት የአብ', 'ላይ ይገኛል። አዲሡ የትምህርት ሥ', 'ሕሥከተል ለተጨማሪ በጊዜው ክ', 'በቫይረሡ ከተጠቁ እናቶች የ', 'ፍረሥ ወዘተ በግለሠቡ ኢኮን', 'ድሥ ማንኜውም ቫይረሡ የተላለፍ', 'ም መሣሪያ ሢፈጥሩ ኽነባሩን', 'ውያዎችና በብዙ ሺህ ኪ።ሜ ርቀ', 'ብደቶችን በዎፍጮ በባቡርና በ', 'ከተሉት ወሣኝ ግኝቶች 1ኡ ነበ', 'መልካም ሥነ-ምግባር ራሥን የመሩ', 'ስም ትውልድ ለማቆየት በዋሻወች', 'ሀገር ባደረገው ሙከራ ለምጅ', 'ህዷቸውም ከነሱ በፊት የተደር', 'ክች ዊልቨር ራይት በ1911 ኦሊእ', 'ና በአምልኳዊ ተግባራት የማዳ', 'ር፥ በ18 አ።ም የተወለደ36።', 'ሞተር ሀይል ይንቀሣቅሣሉ የሠ', 'እፋሎት ሀይል የሚንቀሣቀሥ አ', 'ትሪክ የሚሠሩ ተሽከርከሪዎችም', '- አ።አ ድረሥ የባቡር ሃዲድ ል', 'ኡልም መገደል ላንደኛው አለም', 'ሕ መንግሥት እንዲፈቅድ የሚጠይቅ ን', 'ይማኖት  የዖርቶዶክሥ እምነት ተ', 'ሔደው ጦርነት የተፈለገውን ድል', 'ሥጥ ነው። በጉባዔው የተወሠኑ', 'እድል በውሣኔ ሕዝብ እንዲወሥን የር', 'ውሣኔ ውጤቶች በቀጣይ ለተከሥ', 'ም መንግሥታት ማህበር  አባል መሆ', 'ኧረ-ባሪያ ንግድ አዋጅ በ1924', 'ር ኦሥታሊያና ችኮላቪኪያ ሥ', 'መን በ2ኛ የአለም ጦርነት', 'ሦሻሊሥት ምእራብ ጀርመን እካፒት', 'አባል አገሮች ውሥጥ ኢትዮጵያ', 'ጅት ነበር። ይህ ሚሥጢራዊ ድርጅት', 'ገደደች። ዚምባብዌና ዛምቢያ፥', 'በኋላ በ1994 አፓርታይድ ተግ', 'ሜ ሙሥጠፋ ወዘተ ናቸው። ---', 'አሉት ቀጥለው የቀረቡት ዋና', 'ለእርሻና ለዘሩ አይነት የሚህ', 'ብረት የሚመራ የሦሻሊሥት (ኮ', 'ነጻነታቸውን ተጎናጽፈዋል።']
# Correct characters Rate : 92.60%
# Charcter Error Rate : 6.92%
# Correct Sequence Rate : 77.00%
# Seqence Error Rate : 23.00%

# %%
error_seq

# %%
train_error_seq=0                               #Charcter Error Rate Calculation
Valid_error_seq=0
Test_error_seq=0
total_train_char=0
total_valid_char=0
total_Test_char=0
st=[]
pd=[]
pv=[]
vt=[]
im=[]
train_error=0
valid_error=0
test_error=0
def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]
for i in range (1800):                #Character Error Rate for Train Data Set
    pr = prd_train[i]
    tr = train_original_text[i]
    total_train_char+= len(train_original_text[i])
    if pr != tr:
      train_error_seq+= 1
      st.append(tr)
      pd.append(pr)
    train_error+=levenshteinDistance(train_original_text[i], prd_train[i])
for i in range (200):                  #Character Error Rate for Validation Data Set
    pr = prd_valid[i]
    rrr=valid[i]
    tr = valid_original_text[i]
    total_valid_char += len(valid_original_text[i])
    if pr != tr:
      im.append(rrr)
      pv.append(pr)
      vt.append(tr)

      Valid_error_seq+= 1
    valid_error+=levenshteinDistance(valid_original_text[i], prd_valid[i])
print('Train Set Character Error Rate : %.2f%%' %(train_error*100/total_train_char))
print('Train Set Sequnce Error Rate : %.2f%%' %(train_error_seq*100/1800))
print('Valid Set Character Error Rate : %.2f%%' %(valid_error*100/total_valid_char))
print('Valid Set Sequnce Error Rate : %.2f%%' %(Valid_error_seq*100/200))
# Out:
# Train Set Character Error Rate : 0.02%
# Train Set Sequnce Error Rate : 0.39%
# Valid Set Character Error Rate : 1.68%
# Valid Set Sequnce Error Rate : 23.00%

# %%
for i in range(len(pv)):
  print(pv[i]+"\n"+vt[i])

len(pd)
# Out:
# ጠንካራ ፍለጋ ይጠይቃል። ማዕድን
# ጠንካራ ፍለጋ ይጠይቃል። ማእድን
# ና እሥፔን ነበሩ ከድርጅቱ ዋና
# ና እሥፔን ነበሩ ከድርጂቱ ዋና
# ላይ ይገኛል። አዲሡ የትምድርት ብ
# ላይ ይገኛል። አዲሡ የትምህርት ሥ
# ልሥከተል ለተጨማሪ በጊዜው ክ
# ሕሥከተል ለተጨማሪ በጊዜው ክ
# ዝኔታን የሚፈጥር ቫይረሥ ነው።
# ዝኔታን የሚፈጥር ቫይረሥ ነው።
# ድሥ ማንሜውም ቫይረሡ የተላለፍ
# ድሥ ማንኜውም ቫይረሡ የተላለፍ
# ም ከሣሪያ ሢፈጥሩ ኽነባሩን
# ም መሣሪያ ሢፈጥሩ ኽነባሩን
# ከተሉት ወሣኝ ግኝቶች 1 ነበ
# ከተሉት ወሣኝ ግኝቶች 1ኡ ነበ
# ነልካም ሥነ-ምግባር ራሥን የመሩ
# መልካም ሥነ-ምግባር ራሥን የመሩ
# ሀገር ባደረገው ሙከራ ለመጅ
# ሀገር ባደረገው ሙከራ ለምጅ
# ኧመብረር ምኝት ከተጠናወታቸው
# ኧመብረር ምኞት ከተጠናወታቸው
# ህድቸውም ከነሡ በፊት የተደር
# ህዷቸውም ከነሱ በፊት የተደር
# በማሥወገድ አሥፈላጊውን ጥረት
# በማሥወገድ አሥፈላጊውን ጥረት
# ክች ዊልቨር ራይት በ1911 አሊእ
# ክች ዊልቨር ራይት በ1911 ኦሊእ
# ና በአምኳዊ ተግባራት የማጫ
# ና በአምልኳዊ ተግባራት የማዳ
# ሞተር ሀይል ይንቀሣቀሣሉ የሠ
# ሞተር ሀይል ይንቀሣቅሣሉ የሠ
# እንፋሎት ሀይል የሚንቀሣቀሥ አ
# እፋሎት ሀይል የሚንቀሣቀሥ አ
# ትሪክ የሚሠሩ ተሽከርክ ሪዎችክም
# ትሪክ የሚሠሩ ተሽከርከሪዎችም
# ሉ የአለም ሃያላን ሀገሮች ብ
# ሉ የአለም ሃያላን ሀገሮች ብ
# ይማኖት  የኦርቶዶክሥ እምነት ተ
# ይማኖት  የዖርቶዶክሥ እምነት ተ
# ሌድሕው ጦርነት የተፈለገውን ድል
# ሔደው ጦርነት የተፈለገውን ድል
# ውሣኔ ውጤቶች በቀጣይ ለተከል
# ውሣኔ ውጤቶች በቀጣይ ለተከሥ
# ም መንግሥታት ማህበር አባል መሆ
# ም መንግሥታት ማህበር  አባል መሆ
# ር ኦሥታሊያና ቺኮላቪኪያ ሥ
# ር ኦሥታሊያና ችኮላቪኪያ ሥ
# ጦርነቱም የተባበሩት የጋላክ
# ጦርነቱም የተባበሩት የጋላክ
# መን በ2ኛ የአለም ጦርነት
# መን በ2ኛ የአለም ጦርነት
# ቪያን ሊቱኒያን ከ193-194
# ቪያን ሊቱኒያን ከ1939-194
# ን ያዘ በፈረንሣይም በፓርሻል
# ን ያዘ በፈረንሣይም በፓርሻል
# ቀባል አገሮች ውሥጥ ኢትዮጵያ
# አባል አገሮች ውሥጥ ኢትዮጵያ
# አመት ያገለግላሉ። ይህ ምክር5
# አመት ያገለግላሉ። ይህ ምክር65
# ጅት ነበር። ይህ ሚሥኢራዊ ድርጅት
# ጅት ነበር። ይህ ሚሥጢራዊ ድርጅት
# ፅ (ሦሪያ ኢኢራቅና ዮርዳኖ)
# ፅ (ሦሪያ ኢራቅና ዮርዳኖሥ)
# ሜ ሙሥጠፋ ወዘተ ናቸው። -
# ሜ ሙሥጠፋ ወዘተ ናቸው። ---
# አሉት። ቀጥለው የቀረቡት ዋና
# አሉት ቀጥለው የቀረቡት ዋና
# ለእርሻና ለዘሩ አይነት የሚብ
# ለእርሻና ለዘሩ አይነት የሚህ
# ነጻነታቸውን ተጎናጽፈዋል።
# ነጻነታቸውን ተጎናጽፈዋል።
# 111

# %%
plt.figure(figsize=(15, 20)) #Sample Prediction
for i in range(20):
    ax = plt.subplot(10, 2, i+1)
    plt.imshow(im[i], cmap='gray')
    plt.axis('on')
plt.subplots_adjust(wspace=0.7, hspace=-0.2)

# %% [markdown]
# ## Some predictions on test set

# %%
plt.figure(figsize=(10, 40)) #Sample Prediction
for i in range(30):
    ax = plt.subplot(30, 1, i+1)
    image = im[i]
    #plt.title(print(prd_train[i]))
    #plt.title(print(pv[i] + "     " + vt[i]))
    plt.imshow(image, cmap='gray')
    plt.axis('on')
plt.subplots_adjust(wspace=0.4, hspace=-0.01)

# %%
#Test Set Prediction Implementation
img=[]
test_img_list = sorted(glob.glob('/content/drive/MyDrive/Colab_Notebooks/Nega/test-dataset/test-images/*.PNG')) 
for i, img_path in enumerate(test_img_list):
  ims=cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
  th2 = cv2.adaptiveThreshold(ims,170,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,35,25)
  im=im_resize(th2)
  image = im/255.
  img.append(image)

test_x = np.asarray(img).reshape(-1, 48, 256, 1) #(16384,1)
preds = pred_model.predict(test_x)
decoded = K.get_value(K.ctc_decode(preds, input_length=np.ones(preds.shape[0])*preds.shape[1], 
                                    greedy=True)[0][0])
prd_test = []
for i in range(100):
    prd_test.append(num_to_label(decoded[i]))
# Out:
# 4/4 [==============================] - 1s 35ms/step

# %%
prd_test
# Out:
# ['አቀፍ ፍርድ ቤት 6 የድርጅቱ 64ድ',
#  'እፈት ቤት ጠቅላላ ጉባኤው አብ',
#  'ብብ አገሮችን በሙሉ የሚያካት',
#  'ት ነው። የድርጅቱ ከፍተኛው አካ',
#  'ል ነው። አባል ሀገሮች ተወካይ',
#  'ካ በየ አም።ቱ ኒውርክ ከተማ',
#  'ድርጅቱ ህንያ ውሥጥ እየተገናኙኝ',
#  'ሠባ ያደርጋሉ። እየተከራክ',
#  'ኧሩም ውሣኔዎችን ያሣልፋሉ። መ',
#  'መሪያዎችን ይሠጣሉ። ይሠጣሉ።',
#  'አለም አቀፍ ህጎችን ይደነግጋሉ',
#  'ባጀትም ይመድባሉ። የፀጥታ ጥበ',
#  'ነት ፓርት ድል ተጎናፅ በር',
#  'ቀቀ ሢሆን 5- ቋሚ አባል',
#  'ክት ናቸው። እነሡም፥ አሜሪካ ር',
#  'ሢያ እንግሊዝ ፈረንሣይና ቻይን',
#  'ክ ሢሆኑ ድምፅን በድምፅ የመሻር',
#  'ሥልጣን አላቸው። አ191 ደግሞ',
#  'ጊዜያዊ አባላት ሢሆኑ በየ',
#  ' አመቱ በጠቅላላ ጉባኤ ክ',
#  'ባብ ሀገሮች መካከል የሚም',
#  'ዴግ፥ ናው የምክር ቤቱ ዋና',
#  'ተግባር የአለምን ሠላምና የጥት',
#  'ብ መግበግ ነው። አሥግ ነገር ሥ',
#  '5ህ በወታደራዊ ሀይል እሥክ',
#  'ብ መገቀም ይደርሣል። የኢኮኖም',
#  'ሥና የማህበራዊ ጉዳይ ምክር ቤ',
#  'ት በጠቅላላ ጉባኤዳ 58 አባል',
#  'መድ በልዩ ልዩ ውሃ አካላቶ።',
#  'ውሥጥ የተለያዩ የአሣ ይርያን',
#  'ች ይገኛሉ ለምግብነት የሚውሉት',
#  'የተወሠኑ ይነቶ የሚግ፥',
#  'በት አከባቢዎች አሉ። አሣ ብ',
#  'ኧምት የሚገቸው የድ',
#  'ች 1። በሠሜን ምሥራቅ አትላንት',
#  'ክ 2 የሠሜን ምዕራብ አትላንቲ',
#  'ክ 3። ከሁሉም በላይ በሠሜን',
#  'ምዕራብ ፓሥክ 4 እንዱ-ፓፊክ',
#  '5 መካከለኛው ፓሥፊክ ናቸው።',
#  'ለአሣ መራት በጣም ቀእቃ1',
#  'ህበጣም ሞቃት ሥፍራዎች አመቺ',
#  'አይደሉም ለመሆኑም መካከለኝ',
#  'ብ የሙቀት ክልል አካባቢዎች ከ',
#  'ፍተኛ ክምችት ይታይባቸዋል። አሣ',
#  'ዎች የሚመገቡት ፕላክተን የተ',
#  'ባሉትን ጥቃቅን የውሃ ውሥጥ እፀዋ',
#  'ትን ነውን በተጨማሪም ትላልቅ አ',
#  'ቶ ትናንሽችን ይመገባሉ የእ',
#  ' አመራረት ዘዴ፥ ልማዳዊ',
#  'ጀመናዊ በመባል ይመደባል ልም',
#  'ምዳዊ የዚህ አይነቱ የአሣ እ',
#  'መቀት ኋላ ቀር መሣሪያዎ',
#  'ን የመጠቀምና ያልተቀናጀ ዝ',
#  'ዴን መተቀም ነው። ምርቱም በ',
#  'ግ  ጅጀ ነው መናዊ የተ',
#  '8 ቃት ያላቸውን መሣሪይ',
#  'ብዎ በመጠቀም የማምርበት',
#  'ደቡብ ደዙያ የሚል ነበር።',
#  'በ195 ኢያን ሥፒዝ የሚባል',
#  'ኧኝ ጓደኛ8 ደርሦ አዳነ።',
#  'ተጫዋች አንቺ ኳሥ ድብልብል ላ ግ',
#  'ንደ ልኡል። ለወገኖች ተጨበጪ',
#  'ከእጃችን እንዳትወጪ። ኳሥ ተው',
#  'ቹ ሆይ እንግዲህ ትሠማኝ እንደሁ',
#  'ልምከርህ። መውጣቱሥ አይቀርም እወ',
#  'ቀው ተጋጣሚህ ኳሥ ብል ካለው',
#  'ይልቁንሥ የሚሻለው የጋራ ጥረት',
#  'ማድረግ ነው። ታረም ታዘዝ ለዳ',
#  'ኛው ቅርብ መሆን ጉረኛ። ብዙ ግብ',
#  'ለማሥቆጠር የአጨዋወት ዘዴህ',
#  'ን ቀይር። ተጫወት ችላ ሣትል አት',
#  'ክመንታ ለትግል። አላማህ ማሸነ',
#  'ፍ ብቻ አይሁን መሸነፍም እንዳለ',
#  'ህ እመን። ቀይሥ የፍልሚያ ዘዴ ብ',
#  'ትሸነፍም አትደንግጥ ባንዴ። ብቻህ',
#  'ን ሜዳ ሥትቀዋለል ችሎታህንም ለ',
#  'ወገን አካፍል። ተጫዋች አዳዲ',
#  'ሥ ዘዴዎችን ገብይ እጫወታለው',
#  'በርት። ህግንና ሥረአትን አክብሬ',
#  'እፋወታለው ጠንክሬ። ቃል ገባል',
#  'ኧው በእውነት በሥነሥረአት ልወ',
#  'ት። ድል እመታለው በጨዋታ ምንም',
#  'ኧ። የቀድሞ መጠሪያዋ 78።',
#  'ደቡብ ሮደዙያ የሚል ነበር።',
#  'በ15 ኢያን ሥሚዝ የሚባል ይ',
#  'ኧነጮ መሪ በግሉ ነፃነት በ',
#  'ወጅ በዚምባብ የአናሣ ነ',
#  ' መንግሥት መሠረተ። ጥቁሮቹ',
#  'አፍሪካውያን የዚምባብዌ አፍሪ',
#  'ካውያን ብሄራዊ ማህበርና የዚ',
#  'ምባብ አፍሪካውያን ህዝቦች ማህ',
#  'በሮች የሚሉ ድርጅቶች መሥርተው',
#  'የምቅ ውጊያ ጀመሩ። ከረዥም ው',
#  'ጊያ በኋላ በ1980 ዚምባብዌ',
#  'የነጮችን አገዛዝ አሥወገዱ።',
#  'ነፃ መንግሥት ሆነች። ሮበርት መ',
#  'ጋቤ የመጀመሪያ ፕሬዝዳንት ል',
#  'ሆን በ። ቀደም ሢል ሠሜን',
#  'ፊያ በምትባለው ግዛትም ኬኔ',
#  'ት ካውንዳ የመሠረቱትና የመር']

# %%
tast_y = []
test_input_len = []
test_label_len = []
test_original_text = []
ima=[]
prt=[]
grt=[]
total_test_char=0
test_error=0
test_error_seq=0
with open('/content/drive/MyDrive/Colab_Notebooks/Nega/test-dataset/test-label.txt', encoding="utf-8") as f:
    contents = f.readlines()[0:200]

lines = [line.strip() for line in contents]
for i in range(len(lines)):
  test_original_text.append(lines[i])   
   
def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]

for i in range (100):                  #Character Error Rate for Validation Data Set
    pt = prd_test[i]
    rrr =img[i]
    tr = test_original_text[i]
    total_test_char += len(test_original_text[i])
    if pt != tr:
      ima.append(rrr)
      prt.append(pt)
      grt.append(tr)
      test_error_seq+= 1
    test_error+=levenshteinDistance(test_original_text[i], prd_test[i])
print('Test Set Character Error Rate : %.2f%%' %(test_error*100/total_test_char))
print('Test Set Sequnce Error Rate : %.2f%%' %(test_error_seq*100/100))
# Out:
# Test Set Character Error Rate : 7.81%
# Test Set Sequnce Error Rate : 64.00%

# %%
test_original_text

# %%
prd_test
